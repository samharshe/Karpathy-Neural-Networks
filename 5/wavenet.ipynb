# %% [markdown]
# #  [Makemore part 5: building a WaveNet](https://www.youtube.com/watch?v=t3YJ5hKiMQ0)

# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt # for making figures
# %matplotlib inline

# %%
words = open('names.txt', 'r').read().splitlines()

# %%
from string import ascii_lowercase
stoi = {s:i for i,s in enumerate(['.'] + list(ascii_lowercase))}
itos = {i:s for s,i in stoi.items()}
vocab_size = len(itos)
# I still like this version better

# %%
import random
random.seed(42)
random.shuffle(words)

# %%
# build the dataset
block_size = 8 # context length: how many characters do we take to predict the next one?

def build_dataset(words):  
  X, Y = [], []
  
  for w in words:
    context = [0] * block_size
    for ch in w + '.':
      ix = stoi[ch]
      X.append(context)
      Y.append(ix)
      context = context[1:] + [ix] # crop and append

  X = torch.tensor(X)
  Y = torch.tensor(Y)
  print(X.shape, Y.shape)
  return X, Y

n1 = int(0.8*len(words))
n2 = int(0.9*len(words))
Xtr,  Ytr  = build_dataset(words[:n1])     # 80%
Xdev, Ydev = build_dataset(words[n1:n2])   # 10%
Xte,  Yte  = build_dataset(words[n2:])     # 10%
# Out:
# torch.Size([182625, 8]) torch.Size([182625])
# torch.Size([22655, 8]) torch.Size([22655])
# torch.Size([22866, 8]) torch.Size([22866])

# %%
for x,y in zip(Xtr[:20], Ytr[:20]):
  print(''.join(itos[ix.item()] for ix in x), '-->', itos[y.item()])
# Out:
# ........ --> y
# .......y --> u
# ......yu --> h
# .....yuh --> e
# ....yuhe --> n
# ...yuhen --> g
# ..yuheng --> .
# ........ --> d
# .......d --> i
# ......di --> o
# .....dio --> n
# ....dion --> d
# ...diond --> r
# ..diondr --> e
# .diondre --> .
# ........ --> x
# .......x --> a
# ......xa --> v
# .....xav --> i
# ....xavi --> e

# %%
# Near copy paste of the layers we have developed in Part 3

# -----------------------------------------------------------------------------------------------
class Linear:
  
  def __init__(self, fan_in, fan_out, bias=True):
    self.weight = torch.randn((fan_in, fan_out)) / fan_in**0.5 # kaiming init. legendary.
    self.bias = torch.zeros(fan_out) if bias else None
  
  def __call__(self, x):
    self.out = x @ self.weight
    if self.bias is not None:
      self.out += self.bias
    return self.out
  
  def parameters(self):
    return [self.weight] + ([] if self.bias is None else [self.bias])

# -----------------------------------------------------------------------------------------------
class BatchNorm1d:
  
  def __init__(self, dim, eps=1e-5, momentum=0.1):
    self.eps = eps
    self.momentum = momentum
    self.training = True
    # parameters (trained with backprop)
    self.gamma = torch.ones(dim)
    self.beta = torch.zeros(dim)
    # buffers (trained with a running 'momentum update')
    self.running_mean = torch.zeros(dim)
    self.running_var = torch.ones(dim)
  
  def __call__(self, x):
    # calculate the forward pass
    if self.training:
      if x.ndim == 2:
        dim = 0
      elif x.ndim == 3:
        dim = (0,1)
      xmean = x.mean(dim, keepdim=True) # batch mean
      xvar = x.var(dim, keepdim=True) # batch variance
    else:
      xmean = self.running_mean
      xvar = self.running_var
    xhat = (x - xmean) / torch.sqrt(xvar + self.eps) # normalize to unit variance
    self.out = self.gamma * xhat + self.beta
    # update the buffers
    if self.training:
      with torch.no_grad():
        self.running_mean = (1 - self.momentum) * self.running_mean + self.momentum * xmean
        self.running_var = (1 - self.momentum) * self.running_var + self.momentum * xvar
    return self.out
  
  def parameters(self):
    return [self.gamma, self.beta]

# -----------------------------------------------------------------------------------------------
class Tanh:
  def __call__(self, x):
    self.out = torch.tanh(x)
    return self.out
  def parameters(self):
    return []

# -----------------------------------------------------------------------------------------------
class Embedding:
  
  def __init__(self, num_embeddings, embedding_dim):
    self.weight = torch.randn((num_embeddings, embedding_dim))
    
  def __call__(self, IX):
    self.out = self.weight[IX]
    return self.out
  
  def parameters(self):
    return [self.weight]

# -----------------------------------------------------------------------------------------------
class FlattenConsecutive:
  
  def __init__(self, n):
    self.n = n
    
  def __call__(self, x):
    B, T, C = x.shape
    x = x.view(B, T//self.n, C*self.n)
    if x.shape[1] == 1:
      x = x.squeeze(1)
    self.out = x
    return self.out
  
  def parameters(self):
    return []

# -----------------------------------------------------------------------------------------------
class Sequential:
  
  def __init__(self, layers):
    self.layers = layers
  
  def __call__(self, x):
    for layer in self.layers:
      x = layer(x)
    self.out = x
    return self.out
  
  def parameters(self):
    # get parameters of all layers and stretch them out into one list
    return [p for layer in self.layers for p in layer.parameters()]

# %%
torch.manual_seed(42); # seed rng for reproducibility

# %%
# original network
n_embd = 24 # the dimensionality of the character embedding vectors
n_hidden = 128 # the number of neurons in the hidden layer of the MLP
model = Sequential([
  Embedding(vocab_size, n_embd),
  FlattenConsecutive(8), Linear(n_embd * 8, n_hidden, bias=False), BatchNorm1d(n_hidden), Tanh(),
  Linear(n_hidden, vocab_size),
])

# hierarchical network
n_embd = 24 # the dimensionality of the character embedding vectors
n_hidden = 128 # the number of neurons in the hidden layer of the MLP
model = Sequential([
  Embedding(vocab_size, n_embd),
  FlattenConsecutive(2), Linear(n_embd * 2, n_hidden, bias=False), BatchNorm1d(n_hidden), Tanh(),
  FlattenConsecutive(2), Linear(n_hidden*2, n_hidden, bias=False), BatchNorm1d(n_hidden), Tanh(),
  FlattenConsecutive(2), Linear(n_hidden*2, n_hidden, bias=False), BatchNorm1d(n_hidden), Tanh(),
  Linear(n_hidden, vocab_size),
])

# parameter init
with torch.no_grad():
  model.layers[-1].weight *= 0.1 # last layer make less confident

parameters = model.parameters()
print(sum(p.nelement() for p in parameters)) # number of parameters in total
for p in parameters:
  p.requires_grad = True
# Out:
# 76579

# %%
# same optimization as last time
max_steps = 200000
batch_size = 32
lossi = []

for i in range(max_steps):
  
  # minibatch construct
  ix = torch.randint(0, Xtr.shape[0], (batch_size,))
  Xb, Yb = Xtr[ix], Ytr[ix] # batch X,Y
  
  # forward pass
  logits = model(Xb)
  loss = F.cross_entropy(logits, Yb) # loss function
  
  # backward pass
  for p in parameters:
    p.grad = None
  loss.backward()
  
  # update: simple SGD
  lr = 0.1 if i < 150000 else 0.01 # step learning rate decay
  for p in parameters:
    p.data += -lr * p.grad

  # track stats
  if i % 10000 == 0: # print every once in a while
    print(f'{i:7d}/{max_steps:7d}: {loss.item():.4f}')
  lossi.append(loss.log10().item())
# Out:
#       0/ 200000: 3.3224
#   10000/ 200000: 2.0351
#   20000/ 200000: 2.4314
#   30000/ 200000: 2.3857
#   40000/ 200000: 1.7555
#   50000/ 200000: 1.8885
#   60000/ 200000: 2.0232
#   70000/ 200000: 1.8797
#   80000/ 200000: 1.6253
#   90000/ 200000: 1.7882
#  100000/ 200000: 2.3800
#  110000/ 200000: 1.8485
#  120000/ 200000: 2.0067
#  130000/ 200000: 1.9497
#  140000/ 200000: 1.7484
#  150000/ 200000: 1.9045
#  160000/ 200000: 1.9369
#  170000/ 200000: 1.7868
#  180000/ 200000: 1.8669
#  190000/ 200000: 2.2289

# %%
plt.plot(torch.tensor(lossi).view(-1, 1000).mean(1))

# %%
# put layers into eval mode (needed for batchnorm especially)
for layer in model.layers:
  layer.training = False

# %%
# evaluate the loss
@torch.no_grad() # this decorator disables gradient tracking inside pytorch
def split_loss(split):
  x,y = {
    'train': (Xtr, Ytr),
    'val': (Xdev, Ydev),
    'test': (Xte, Yte),
  }[split]
  logits = model(x)
  loss = F.cross_entropy(logits, y)
  print(split, loss.item())

split_loss('train')
split_loss('val')
# Out:
# train 1.7659443616867065
# val 1.9930835962295532

# %% [markdown]
# ### performance log

# %%
# sample from the model
for _ in range(1000):
    
    out = []
    context = [0] * block_size # initialize with all ...
    while True:
      # forward pass the neural net
      logits = model(torch.tensor([context]))
      probs = F.softmax(logits, dim=1)
      # sample from the distribution
      ix = torch.multinomial(probs, num_samples=1).item()
      # shift the context window and track the samples
      context = context[1:] + [ix]
      out.append(ix)
      # if we sample the special '.' token, break
      if ix == 0:
        break
    
    print(''.join(itos[i] for i in out[:-1]).capitalize()) # decode and print the generated word
# Out:
# Cordan
# Khalique
# Idayesh
# Barlin
# Khaleya
# Yohania
# Caliopion
# Geonna
# Sameia
# Dimoni
# Gundaya
# Maliana
# Isabella
# Avie
# Peyler
# Nolto
# Izechanse
# Quaii
# Aleksandra
# Giahima
# Jenisom
# Deanxa
# Rockland
# Blakeyla
# Adelgan
# Antella
# Maylor
# Odean
# Kealon
# Vaela
# Hassad
# Serenica
# Benjamin
# Braxlee
# Aeris
# Aariyah
# Ernika
# Briario
# Aalaniyah
# Avi
# Macey
# Damonhi
# Tamari
# Alyrnie
# Kenzlie
# Nalin
# Cally
# Theago
# Namira
# Addelani
# Yanelis
# Azionhu
# Raylea
# Benessa
# Nidorat
# Keilynn
# Kjayer
# Kamrlyn
# Danell
# Safah
# Maydie
# Daxx
# Milesa
# Hameron
# Abrias
# Kamani
# Braxley
# Ryan
# Emiliana
# Eeronide
# Rhilin
# Coannie
# Martavious
# Zeniel
# Gerrick
# Rakhi
# Jacson
# Quincy
# Mantrell
# Mollee
# Emmersha
# Bayir
# Louasii
# Samarej
# Aneel
# Zaddee
# Hunton
# Eza
# Asaan
# Thakandel
# Jadie
# Finnio
# Loren
# Kamarie
# Stefeanious
# Ahlan
# Giuson
# Emry
# Deslen
# Burklyn
# Jandermony
# Azul
# Keymon
# Briopeid
# Labaedah
# Brix
# Javiane
# Adlin
# Haviana
# Luciel
# Avalynne
# Azaelish
# Kaelyn
# Sang
# Wilton
# Ady
# Majayion
# Nehira
# Sophion
# Laurelie
# Ifiandra
# Sestefani
# Derrick
# Mariamah
# Mattison
# Alessandro
# Nayella
# Gooda
# Sajiha
# Timona
# Jaticus
# Vontrell
# Jazlil
# Aphina
# Maadley
# Rilyn
# Davida
# Namber
# Celestino
# Thel
# Mattlsud
# Arra
# Enzie
# Emor
# Milliah
# Stapham
# Aizona
# Kaisen
# Yaoshay
# Benecianna
# Indek
# Otton
# Attalia
# Xayveeth
# Parolina
# Novan
# Eilahni
# Jaheem
# Dalarie
# Alesaand
# Hollie
# Paizley
# Roiah
# Karrington
# Mcklynn
# Demcie
# Ruwaido
# Keitor
# Payslee
# Doaya
# Madge
# Janyla
# Elden
# Jerziyah
# Ladlynn
# Naoya
# Amilo
# Sohaan
# Cybenne
# Brooklee
# Malkiya
# Jaylen
# Shayes
# Attziah
# Tyanne
# Lilianny
# Iohamsh
# Jaelie
# Abdourar
# Indi
# Gurbay
# Malania
# Yahden
# Yasriel
# Han
# Lexandro
# Zarom
# Giovanna
# Araia
# Zaydah
# Monte
# Trisad
# Brena
# Laianna
# Kaelon
# Beyte
# Mykko
# Emelle
# Cainen
# Eduah
# Millixe
# Luxx
# Aayland
# Simano
# Betsyn
# Siman
# Jaimee
# Elyanna
# Roheva
# Daison
# Eley
# Tati
# Tesome
# Calany
# Brookley
# Dontae
# Kayli
# Easti
# Fartin
# Dillope
# Samar
# Henslee
# Robert
# Toluwaioma
# Jaquon
# Kaina
# Stoksean
# Aura
# Dayven
# Tejla
# Angellie
# Tobyn
# Emrah
# Kavine
# Matthey
# Malaxay
# Bathire
# Sadney
# Sayra
# Jerma
# Fatemina
# Yowe
# Kharlie
# Aasshana
# Akshann
# Kenzie
# Ayta
# Lagni
# Antona
# Avalie
# Viva
# Elenet
# Tzara
# Dionna
# Jeovan
# Kemailh
# Muhana
# Roema
# Desjie
# Nanvi
# Yubert
# Mikal
# Joel
# Andres
# Hartler
# Colmue
# Manobylai
# Naaro
# Sameeman
# Serge
# Neylani
# Ailia
# Ethen
# Rayton
# Angelio
# Eta
# Sala
# Avin
# Hollen
# Dalcine
# Mankam
# Fayn
# Elyla
# Ezlan
# Kairo
# Samine
# Adris
# Athensen
# Cheya
# Aidan
# Mikiyah
# Samanta
# Lirlah
# Adeline
# Jhansh
# Guades
# Ilson
# Kaysen
# Shamizley
# Jaselin
# Canee
# Lucilyn
# Nireon
# Akilyn
# Aarym
# Hela
# Kalvyn
# Topia
# Miyora
# Sergey
# Odyanna
# Ria
# Alisa
# Kaleena
# Knoch
# Baylyn
# Kataliha
# Winsley
# Francesca
# Mavleanna
# Jescesa
# Beardy
# Lindel
# Kerri
# Raiya
# Tema
# Alexander
# Jancarlo
# Yque
# Dariyan
# Meliah
# Marty
# Shelby
# Lawsyn
# Rumi
# Quint
# Lyndy
# Arri
# Kalo
# Ryleigh
# Jaileigh
# Josselyn
# Pranton
# Andrae
# Abree
# Iymoree
# Jaydeejah
# Virac
# Gianelle
# Mianah
# Zalen
# Yuhana
# Brynley
# Ockwill
# Emmazine
# Shyorah
# Adnabelle
# Ashlin
# Thorna
# Trani
# Daymier
# Baylen
# Isathan
# Juvigan
# Aamara
# Leon
# Jhavia
# Sorina
# Saney
# Hamsi
# Lytef
# Terron
# Thiancisio
# Jaedo
# Jacks
# Malana
# Haelyn
# Kynsley
# Dea
# Willow
# Dylene
# Yasmel
# Jakyra
# Brexley
# Xion
# Augustino
# Ezekio
# Milaire
# Julianna
# Jajki
# Asrish
# Demilius
# Jarin
# Leias
# Sahab
# Tathan
# Turalyn
# Jael
# Kaileena
# Demonte
# Kajumi
# Blaykent
# Braylen
# Avyna
# Josariq
# Samin
# Netchia
# Delayna
# Jarayah
# Binna
# Cardon
# Alanna
# Zakarriano
# Hayley
# Makey
# Abdullianne
# Kimo
# Antlaia
# Bradtem
# Kenma
# Jayonna
# Zyon
# Melaibel
# Eliiana
# Lipir
# Hoace
# Cabby
# Abag
# Daisyn
# Semarion
# Kaizise
# Abigaurie
# Leena
# Bake
# Deslin
# Carlissa
# Takai
# Gian
# Trinity
# Rylan
# Reys
# Charleen
# Jairielle
# Maxza
# Adison
# Zaina
# Lucas
# Jengan
# Kylany
# Romeland
# Kylyn
# Lakou
# Sephuby
# Maagley
# Cabyree
# Azzy
# Nareem
# Rhyder
# Mikaima
# Demya
# Zoey
# Domanus
# Malakhia
# Kalya
# Blayklynn
# Jaxlynn
# Jaylin
# Demarro
# Vanal
# Kohris
# Bridgeth
# Oloux
# Jaylenne
# Boyna
# Arafel
# Kiana
# Shillia
# Isabella
# Nao
# Hanel
# Scushadi
# Gitton
# Jaelly
# Dina
# Darrion
# Ronin
# Gressucho
# Dilyon
# Ealani
# Zahir
# Asien
# Sumeya
# Oswae
# Rain
# Kynon
# Elaina
# Rii
# Bain
# Mackim
# Jefred
# Dana
# Princeta
# Keil
# Falla
# Miarapilo
# Azavia
# Jaiceh
# Izland
# Nicki
# Charsh
# Leanna
# Airiel
# Matthea
# Azzir
# Chrison
# Aren
# Blaum
# Khauda
# Davontae
# Jaelen
# Laiyah
# Keer
# Caidon
# Thorry
# Javon
# Rigland
# Jamiko
# Natari
# Asaaysha
# Tamiles
# Passi
# Willowd
# Naneem
# Ollee
# Zupeyr
# Kemaii
# Rishama
# Spouli
# Tricennon
# Gidbry
# Larabelle
# Aalerah
# Jailian
# Samari
# Yosiree
# Jaquar
# Elia
# Yovanni
# Quinn
# Calin
# Brodigia
# Kennan
# Soleia
# Princedavi
# Willa
# Lumar
# Tahmode
# Bralie
# Breklyn
# Daley
# Semeya
# Juli
# Ahriyah
# Hollyn
# Karisda
# Isla
# Moylie
# Raelle
# Kymin
# Winsley
# Rishaan
# Johnford
# Cash
# Ruway
# Tymee
# Abdroseynn
# Maheala
# Abdu
# Aldyn
# Ashvika
# Tamilia
# Hous
# Andree
# Jasii
# Ahton
# Lavaya
# Havlah
# Edgerro
# Clarah
# Kallan
# Sanja
# Emora
# Jamari
# Aliyana
# Ezine
# North
# Atifa
# Hayazir
# Maire
# Isaioah
# Anonle
# Levin
# Marybella
# Raley
# Deline
# Wrenley
# Jamerah
# Akhary
# Brooce
# Ashawn
# Dimari
# Kenlin
# Uzelyn
# Jeyonna
# Fahzi
# Sabastian
# Polasayd
# Macasa
# Kyzion
# Lillie
# Adriah
# Ahsher
# Simberly
# Gianla
# Cot
# Avery
# Jaden
# Jalem
# Makayel
# Damonte
# Aehfani
# Millie
# Yarson
# Youstin
# Talayia
# Emry
# Thakin
# Agusea
# Shaunah
# Haisla
# Santison
# Niriah
# Alika
# Williome
# Kahleeana
# Aarun
# Umilia
# Adely
# Adelai
# Donolana
# Dalena
# Delane
# Ishawn
# Rawdon
# Gaida
# Jaziah
# Bouri
# Osirra
# Jahmir
# Aleksair
# Mana
# Quavin
# Cheyon
# Zoeena
# Briyana
# Kamaya
# Lorelia
# Alaylah
# Neiche
# Mali
# Heric
# Shee
# Jakyla
# Darlyn
# Emilyr
# Rhensen
# Lailany
# Nzeyah
# Jazzlee
# Giovanou
# Dilani
# Amaa
# Jalena
# Wiltrowad
# Thaliya
# Jaylani
# Yanis
# Azzir
# Presh
# Aadhion
# Alsean
# Aveayah
# Vivianni
# Airlee
# Yenna
# Azzal
# Eisa
# Lyla
# Gatzin
# Roselina
# Zaylia
# Imir
# Alexi
# Vaidey
# Lisky
# Adiela
# Avaleen
# Dwyldo
# Wilder
# Daniyah
# Hailyn
# Aviana
# Xaneh
# Kahlan
# Rebechukwu
# Krista
# Itzael
# Zephary
# Haralyn
# Navaina
# Alazia
# Draidu
# Thala
# Neil
# Jamie
# Emmalea
# Devayah
# Kaina
# Callie
# Takaro
# Maraii
# Jeyn
# Khilia
# Andersyn
# Epatrino
# Elisabeth
# Kryzer
# Jeovani
# Oluwatotias
# Arria
# Huxton
# Sraretta
# Lonel
# Cardowe
# Shanyl
# Jimiiah
# Juliana
# Heru
# Dreyad
# Liviis
# Ecien
# Izaiah
# Angelo
# Nover
# Tobynae
# Rickolars
# Zameri
# Timiah
# Aashlez
# Matumeire
# Laf
# Kaylor
# Aravious
# Aranya
# Riyany
# Raeya
# Shamyke
# Shivance
# Abraana
# Kailase
# Liabiana
# Sahil
# Dwayne
# Eveia
# Demaora
# Abigan
# Raegan
# Azarii
# Antonie
# Wrever
# Arson
# Kalyiah
# Kalena
# Azarion
# Haryl
# Livanah
# Bolyen
# Jered
# Zina
# Raidi
# Brancen
# Nazarah
# Arlany
# Yazmietia
# Kashira
# Calel
# Yaniel
# Aasha
# Lewi
# Jakyla
# Alatana
# Hermiq
# Isli
# Arsh
# Juanzura
# Zoha
# Davannah
# Orvin
# Elayah
# Kamrii
# Roselle
# Denola
# Izabella
# Darriyah
# Eplynnley
# Jaretzz
# Amadou
# Loust
# Nithit
# Honorah
# Embyn
# Jocelynn
# Aamya
# Diyan
# Tejon
# Calaria
# Afana
# Iviandrus
# Jaice
# Yehudie
# Brixleigh
# Amari
# Leannah
# Cayden
# Josslynn
# Mathel
# Ashlen
# Thadas
# Jumeir
# Dasiel
# Somuna
# Sultaira
# Nilani
# Sevilne
# Tadaya
# Yelan
# Alelah
# Wildon
# Nikko
# Deshawn
# Enrix
# Minachimua
# Ray
# Jakai
# Janel
# Zaharri
# Xaiya
# Ezala
# Luciana
# Bega
# Nikolas
# Finiar
# Kellion
# Legen
# Denisse
# Elen
# Asandree
# Whitley
# Jazzperell
# Sawny
# Habella
# Aubrie
# Jailey
# Zihira
# Jenicia
# Kauri
# Kabier
# Sophila
# Kalyse
# Glenna
# Sictoria
# Mauri
# Asaan
# Karyn
# Tophanie
# Laryose
# Kaggen
# Kiena
# Stelsta
# Yuvan
# Dwaydon
# Eveley
# Journie
# Maiza
# Maddyke
# Beva
# Lemond
# Abriah
# Nathenja
# Othi
# Bethna
# Ijedad
# Dionru
# Winna
# Jaileen
# Clarron
# Mithika
# Leyrio
# Brigrand
# Cait
# Vanny
# Nemi
# Nachi
# Randrew
# Olenie
# Daomio
# Brindyn
# Elella
# Laighan
# Leenah
# Akitan
# Storman
# Paeton
# Dil
# Jeyroo
# Samjah
# Bukiyah
# Brayla
# Nijah
# Isibelle
# Ramon
# Nikoli
# Lorely
# Brisadh
# Mijan
# Lindon
# Gorra
# Riyandea
# Shraton
# Ritvi
# Riney
# Harleigh
# Taye
# Bethanie
# Shrage
# Ayelle
# Grayton
# Norianna
# Thiia
# Iverie
# Giulio
# Tevyanna
# Everick
# Gylinna
# Melia
# Alaya
# Halayza
# Avaleria
# Rozolant
# Thai
# Asmary
# Camara
# Blohana
# Lyrand
# Raeliyahro
# Georgiose
# Zaxton
# Jeyveon
# Adiel
# Genesyn
# Jerick
# Kalev
# Gentavious
# Risha
# Jamilani
# Gretta
# Milliana
# Adrace
# Aislyn
# Bayla
# Noralynn
# Binton
# Aleemes
# Emiling
# Lindson
# Speyra
# Madhya
# Riyanna
# Vlott
# Arienna

# %%
for x,y in zip(Xtr[7:15], Ytr[7:15]):
  print(''.join(itos[ix.item()] for ix in x), '-->', itos[y.item()])
# Out:
# ........ --> d
# .......d --> i
# ......di --> o
# .....dio --> n
# ....dion --> d
# ...diond --> r
# ..diondr --> e
# .diondre --> .

# %%
# forward a single example:
logits = model(Xtr[[7]])
logits.shape
# Out:
# torch.Size([1, 27])

# %%
# forward all of them
logits = torch.zeros(8, 27)
for i in range(8):
  logits[i] = model(Xtr[[7+i]])
logits.shape
# Out:
# torch.Size([8, 27])
